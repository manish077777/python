# %% [markdown]
# ![image.png](attachment:9d93784e-dd65-486c-8d7b-ca903734c97f.png)

# %%
#print "Hello, Python World!"
print("Hello, Python World!")
# Out:
# Hello, Python World!

# %%
#program that takes a user's first and last name as input and prints them in reverse order with a space between them.
a= input("Enter the First name :")   #takes a user's first name as input 
b= input("Enter the Last name :")  #takes a user's second name as input 
c= a+ " " +b # Concatenate the strings `a` and `b` with a space in between, and assign the result to `c`
print(c[: :-1]) #reverse order of the input string
# Out:
# Enter the First name : Manish
# Enter the Last name : Sharma
# amrahS hsinaM

# %%
# program that takes an input number from the user, converts it to different numeric data types (integer, float, and complex), and displays
a = int(input("Enter the number :")) #integer input from user and store in varaible a 
b = input("IN WHICH DATATYPE YOU WANT TO CONVERT FOR INT TYPE int FOR FLOAT TYPE flt FOR COMPLEX cmp ") #Then ask to user in thich dataype  want to conver if they want interger type int otherwise for float type flt or if they want complex then type cmp 
if b=='int': #if user type int then this parst of code execute that why we use if elif statement in this part
    d = int(a) #and then we use type casting and convert the user input to integer and store in a new variable d 
    print("The Interger Value is" , d) #and then print d 
elif b=='flt': #in case user type flt then this part of code is executed 
    d = float(a) #and same data casting work here also and convert user input into float 
    print("The Float Value is" , d) #and print d 
elif b=='cmp' : #if user tye cmp then this part of code execute that why we use elif in both 2nd and 3rd line 
    d=complex(a) #in this user input is converted into complex number 
    print("The Complex Value is " ,d) 
#then print d
# Out:
# Enter the number : 07
# IN WHICH DATATYPE YOU WANT TO CONVERT FOR INT TYPE int FOR FLOAT TYPE flt FOR COMPLEX cmp  flt
# The Float Value is 7.0

# %%
# calculates the area of a rectangle
Length = int(input("Enter the Length :")) #input the length by user
Breadth= int (input("Enter the Breadth: ")) #input the breadth by user
Area = Length* Breadth # multiply length and breadth to calculate Area
print("The Area of Rectangle is " , Area) #print the Area of Rectangle
# Out:
# Enter the Length : 4
# Enter the Breadth:  3
# The Area of Rectangle is  12

# %%
#three numbers as input and prints their average using the % method for string formatting.
a = int(input("Enter first number:"))#input the first number
b = int(input("Enter second number:"))#input the second number
c = int(input("Enter third number:"))#input the third number
average = (a+b+c)/3 #add a,b,c aqnd divide by 3 to find the average
print("Average of three number :%.2f" % average) #print the result of average
# Out:
# Enter first number: 4
# Enter second number: 4
# Enter third number: 4
# Average of three number :4.00

# %%
#asks the user for a number and determines whether it is positive, negative, or zero
Number = int(input("Enter the number:"))#input the integer number
if Number>0:# by using if condition ,if number is greater than zero then print Positive
    print("The Number is Positive")
elif Number<0:#by using elif condition ,if number is less than zero then print Negative
    print("The Number is Negative")
else:#by using else condition ,if any other number then print zero
    print("The mumber is zero")
# Out:
# Enter the number: 0
# The mumber is zero

# %%
while True: 
    # Ask the user for input
    user_input = input("Enter a number (or type 'exit' to quit): ")
# Check if the user wants to exit
    if user_input.lower() == 'exit': 
        print("Exiting the program Goodbye!")
        break 
    else:
        # Convert input to a float and determine if it is positive, negative, or zero
        number = float(user_input) 
        if number > 0: 
            print("The number is positive.") 
        elif number < 0:
            print("The number is negative.") 
        else: 
            print("The number is zero.")
# Out:
# Enter a number (or type 'exit' to quit):  4
# The number is positive.
# Enter a number (or type 'exit' to quit):  0
# The number is zero.

# %%
#script that takes two numbers as input and prints whether both numbers are even, odd, or one of each using relational and logical operators
First_number = int(input("Enter the first number: ")) 
Second_number = int(input("Enter the second number: ")) 
# Check whether both numbers are even, odd, or one of each using relational and logical operator 
if First_number % 2 == 0 and Second_number % 2 == 0: 
    print("Both numbers are even.") 
elif First_number % 2 != 0 and Second_number % 2 != 0: 
    print("Both numbers are odd.") 
else:
    print("One number is even and the other is odd.")
# Out:
# Enter the first number:  6
# Enter the second number:  6
# Both numbers are even.

# %%
# program that takes an integer input and prints its binary, octal, and hexadecimal equivalents using a for loop and bitwise operators.
def convert_number(num): 
    # Binary conversion 
    binary = '' 
    for i in range(num.bit_length(), -1, -1):
        binary += '1' if (num >> i) & 1 else '0' 
    binary = binary.lstrip('0') or '0' # Remove leading zeros 
    # Octal conversion 
    octal = '' 
    for i in range(num.bit_length() - 1, -1, -3): # Group by 3 bits for octal 
         octal_digit = (num >> i) & 7 # Extract 3 bits at a time 
         octal += str(octal_digit) 
    octal = octal.lstrip('0') or '0' # Remove leading zeros 
    # Hexadecimal conversion 
    hex_digits = "0123456789ABCDEF" 
    hexadecimal = '' 
    for i in range(num.bit_length() - 1, -1, -4): # Group by 4 bits for hexadecimal 
         hex_digit = (num >> i) & 15 # Extract 4 bits at a time 
         hexadecimal += hex_digits[hex_digit] 
    hexadecimal = hexadecimal.lstrip('0') or '0' # Remove leading zeros 

    print(f"Binary: {binary}") 
    print(f"Octal: {octal}") 
    print(f"Hexadecimal: {hexadecimal}") 
# Take integer input from the user 
number = int(input("Enter an integer: ")) 
convert_number(number)
# Out:
# Enter an integer:  4
# Binary: 100
# Octal: 1
# Hexadecimal: 1
